# %%
import warnings
warnings.simplefilter('ignore')

import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# # Generacion de texto a nivel de letra

# %% [markdown]
# **descarga de datos**

# %%
import keras
import numpy as np


path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')


text = open(path).read().lower()


print('Corpus length:', len(text))
# Out:
# Corpus length: 600893
# Using TensorFlow backend.

# %% [markdown]
# **vectorizando secuencias de caracteres**

# %%
maxlen = 60     # secuencias de 60 caracteres
step = 3        # muestras de 3 letras

sentences = []

next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print('Number of sequences:', len(sentences))
# Out:
# Number of sequences: 200278

# %%
chars = sorted(list(set(text)))  # caracteres unicos
print('Unique characters:', len(chars))


char_indices = dict((char, chars.index(char)) for char in chars)
# Out:
# Unique characters: 57

# %%
print('Vectorization...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

print ('Done!!')
# Out:
# Vectorization...
# Done!!

# %% [markdown]
# **modelo de una sola capa LSTM, se predice siguiente letra**

# %%
from keras import layers


model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))


optimizer = keras.optimizers.RMSprop(lr=0.01)


model.compile(loss='categorical_crossentropy', 
              optimizer=optimizer)

# %% [markdown]
# **funcion para muestrear siguiente letra dada la prediccion**

# %%
def sample(preds, temperature=1.0):
    
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    
    exp_preds = np.exp(preds)
    
    preds = exp_preds / np.sum(exp_preds)
    
    probas = np.random.multinomial(1, preds, 1)
    
    return np.argmax(probas)

# %% [markdown]
# **loop de generacion de texto**

# %%
import random
import sys

for epoch in range(1, 15):  # sube epocas
    print('epoch', epoch)  
    model.fit(x, y, batch_size=128, epochs=1)
    
    start_index = random.randint(0, len(text) - maxlen - 1) 
    generated_text = text[start_index: start_index + maxlen] 
    print('--- Generating with seed: "' + generated_text + '"')
    
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            
            preds = model.predict(sampled, verbose=0)[0]
            
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 123s 614us/step - loss: 2.0206
# --- Generating with seed: ".=--it proves a material gain to
# him who would attain knowle"
# ------ temperature: 0.2
# .=--it proves a material gain to
# him who would attain knowledge and the same its insting the stimater of the stillose and the stilloses the stillose the stillowed stillose of the perplession of the still of the stillose the stillose of the stillose of the strengther and the stillose of the stillose of the prifes the preperity of the preference of the preference of the ferest of the believe the stillose of the present of the stilloses and the string the see------ temperature: 0.5
# llose of the present of the stilloses and the string the seem to be discurit of
# pleasure for the strined of the forder not all the string of the possibition and the men a man the heart to himself the stelled to
# the vay be the descience find of the perplecess of spirit is in the prifour of the fellond of the present is the decasation of the stimpless of his istence, as the betreatt of the pripery of the find and deart of the sort the perpence of the still p------ temperature: 1.0
# f the find and deart of the sort the perpence of the still plowed without permence athated to the bood "forte,
# ond beistrase indnce to the beloor pission for recoorditosel a geind is, would
# fart, subting, as and the now the yet primiced to pre!sonce and the feeling firhul it is thumn for
# whorle notelyatic and deelve by after of its entimatibery the avent very meally of the fan betore sougnismin vay of
# in what this they--the of gor: to the effer if
# shat gra------ temperature: 1.2
# y of
# in what this they--the of gor: to the effer if
# shat gratestol--fglibe, which tover. up, perhrstivates so-cran: exretee--bromided a prefine, he have
# a othachation.
# i  qlife all manytifice," and
# put-is.
#
#
#
# 1o cagiod" it to haped enlysifits--woscness corrt stach not
# inethen as thes, foroth been ps sourt dy playanes,, why vertest litm!
# ggeith.
# mirthous;eply itself
# of
#
#  pat is beonkfre: bath!t ensthely hy man itleet, any oratr,
# indegminigy sts a, pressibeepoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 133s 665us/step - loss: 1.6418
# --- Generating with seed: "at a variety of conversations) to be the cause of the declin"
# ------ temperature: 0.2
# at a variety of conversations) to be the cause of the declines and still present and the problem and who has a the moth and who has only and who have and thinked and who has not and thinked the stince and morality of the problem of the self-condition, and and the world and who condition of the self-contemply of the spirit of the conscience, and the problem and who condition of the self-condition of the contrance of the most condition of the propestion and ------ temperature: 0.5
# f the contrance of the most condition of the propestion and only man it is with our case and most of the propery any
# spirited as the conscience, and religic no long to and the defunes which the must case and "present, exmand of the bread and it be saye with a the destrusted to religits constinue and things, and stiption and with every problem and men and in the proceutic and who have the enjodctically and have to a shame to a long the sting to falsely for ------ temperature: 1.0
# ally and have to a shame to a long the sting to falsely for else as madicire) simned, thitheg sensuoch elgo and belief disacried:
# ithy the getine, and and
# instinction is wronk one an
# the delight belung with more inveratest, defore as a named
# toi
# ranjently extent, and force which staten sy thoughs, at it
# moralsed of luputh
# lubogon. who rodts, if evolunt, unthings
# corpretuiaging, asiect has arcuold
# munter,
# harment: a powle, are cond ancturual arditele. the ------ temperature: 1.2
#
# munter,
# harment: a powle, are cond ancturual arditele. the forgre
# s . "the but" who weuldinef viewd, to
# indiniblts
# diffortre
# partaodly vensed-exarplely indestrubtulance is nom wat fear thought it
# of ordinsuthes and
# prozed srite? it opletiesg
# to orgneks (not for anvious orguniay, god-to upminen
# this could (most thinkenwer, as thereby himself with flongly may winliging allaitamayithis truc, adrelong wh thinging forceriared-nar reluubitanaluged to tarmounefepoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 138s 691us/step - loss: 1.5484
# --- Generating with seed: "as the buffoon and satyr are foreign to him in body and cons"
# ------ temperature: 0.2
# as the buffoon and satyr are foreign to him in body and consequences of the same the general the same spirit the same to the same the same the same moral and more and the same to a profound the same the same the same the same the world to the same we may and the same the same the fact to the same in the same the profound to the same has a problem the same the same we cannot the same the same the contemptation of the same the spirit the self and are say, th------ temperature: 0.5
# ontemptation of the same the spirit the self and are say, the are still in the same distristory that the same that the bound the sour and an interpretious shame fation of the will the sense in the for the problem of the great respect to hard should be as
# for the sided of the for the prompt of sublimes to it entiment in the loves speak soul--the most world and which is the most the serve the desirate or a distanted pre; when the same world that the preventa------ temperature: 1.0
# te or a distanted pre; when the same world that the preventas countree agaiding promption as against that it a d toobmery are ears it
# is
# strengthing, and was is explactays which
# superaunicas.--is atasted to has as
# a well.
#
#  the sensed, to enfear-himself is reason to say, with the desimops of phidogiones resist should to fexillycitation, and there is cause nothing the invaning to ouchasificatial.
#
#
# decamption. "obwer; the most philosod is to althing much is------ temperature: 1.2
#
# decamption. "obwer; the most philosod is to althing much is acknymeth and good that ondispcate to the "theiphian to sed, to in
# stying to undistlays tochate ssoell fraction--was any colmoseflywabinaties mnokening or willo--ign philosopagiviag amas of the cluss the look flordeet", away kriests, no
# anriationsful his
# wase
# nofmost an lage some flore.
#
#
# 1ne the necessary perhaps would displonisily virtuol withisat willougs
# lack, it is were
# is ety rewathyfience epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 153s 762us/step - loss: 1.4984
# --- Generating with seed: "ns against good
# taste, but is also an incentive to sins of o"
# ------ temperature: 0.2
# ns against good
# taste, but is also an incentive to sins of our a desire of the same the more the strength of the something the consequently and the stronger the more the strange of the string and desire of the same to the fear of the string that the strength the stronger the morality, the soul--the something and and the contempority of the sentiment of the strongest the stronger of the strongest and something and the sentiment of the sure the soul--and the------ temperature: 0.5
# nd something and the sentiment of the sure the soul--and the fact something to be and the man is to the end to curselntism and restries of the greatest higher this errore. and the end the soul, in the fact
# and or the for their some case and suffering of the other far of the same causality of the self-determfully that as a self-art, and in the distinction, and such the passion itself, and the the greatest considerate the erroring that called case of a more ------ temperature: 1.0
# reatest considerate the erroring that called case of a more res deferently sacre, in resoluse aircelobitive, he so gre shot hem their appear who, in these senwitic and it sunerrof say, all smeduantfulness and new morality). as againfulation"his desire to maniverterm, at littlangs "the (yer careityes whether amountyeg or worth, volunted on ready tome have not spres imentitures enduriable ruld apposted, to persony of the herefor we, arts of philosopher-super------ temperature: 1.2
# ted, to persony of the herefor we, arts of philosopher-superiode as it
# sinnerooring, doomeness to soi, bad
# in the smetter ourse for gans, sommanness--his sonhinage,
# themose pain proves continualsy; "from a, to
# so caustime
# liginess, most houisifiantious mepory of
# honort
# indogation chilontentres, the "coasel or ichitives,
# maordanually, indorstand of and moraliy believen
# ands,
# us of morents. ler more
# of "bicture only upon origine helo"enesoly, itself. the amtepoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 155s 776us/step - loss: 1.4665
# --- Generating with seed: "re requires pardon and
# transfiguration; there is nothing tha"
# ------ temperature: 0.2
# re requires pardon and
# transfiguration; there is nothing that the problem of the superates and the string the spirit of the same to the self-consequently be the power of the sense of a conscience of the soul to the spirit of the same and the conscience of the constant to consequently and contrary and the most will to the same and the sense of the subtles and some should have some the strong the subtles of the soul and in the self-consequently and deces and------ temperature: 0.5
# btles of the soul and in the self-consequently and deces and the sense of the sublime and because and has as a man the contralict of the same in the charm, and race the sense that a matering and nothing of a moral has and his and to which well to the false of the consider of a femiling of the cruse, and he of the respect, and has constrange of the facts so the subtles the fainful and what to be and to the all man has to a longer and should be and a moralit------ temperature: 1.0
# d to the all man has to a longer and should be and a morality the only tith a "faighs,
# proorriusary hfle"ans, of natures
# is influnge, but pleasure were hand very will faiths. we nobedisold with and the min before every a same easy the must and dhide and
# clide soul, we has
# sout" so the
# conscience of man tranghts is hard tern both thad iffecter. instance hands and
# confound, bood
# coure. thus deluth wentogent to a great his utawily asponsublate themselves wien------ temperature: 1.2
# entogent to a great his utawily asponsublate themselves wienwy, no joy and ded and sleasting means. thinkong mat! here is,
# asponcead
# hasted believe he is
# as he culfoly, which dorn
# shout that the
# shall-thems oftingion,
# so
# can promlebure it dicruan," he sympat, most richlage is houtes and excaye he using,
# and  neartaunady.
# naturance
# act,
# nevertheke beens more powerabis! the ourselves. "knisot
# convaluation. man brorge ovisonifes "what ilfulculr, which athuallepoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 172s 858us/step - loss: 1.4449
# --- Generating with seed: "tain, that illusion is less valuable than "truth" such valua"
# ------ temperature: 0.2
# tain, that illusion is less valuable than "truth" such valuation of the present the same the subjection of the conscience and spirits of the present species and will the sense of the present itself and loved the sense the present of the sense of the profeined of the present with the same the present of the sense of the sense of the same the sense and spirits of the spirits of the same the same the same the present the sense of the self-general and spirit a------ temperature: 0.5
#  same the present the sense of the self-general and spirit and there"--there is it even the help to the fact the truth and econdent the one with its who are speaks; the part of the have so same are in the sporition of the spirits: i are and according the present the one readily them to the present of the disclosed itself in results he is the world the same morality of the are of the spirit experience who had been many been indivilued the desire to be such ------ temperature: 1.0
# nce who had been many been indivilued the desire to be such nature, for
# the slowly the good duwr" and in2-artist men
# shencefiture. for human lover of fasters from
# the mesterity"; a bosts of examped of rending man not wholl"
# even in the finerged," feels it deceited ady conerfeeps of the exinctation from the plail, involuntarily there--a first is practiceness, there is calletied toledial.--abnity
# peilon
# moral dars, is disadpant and will to old and
# which the
# ------ temperature: 1.2
# ilon
# moral dars, is disadpant and will to old and
# which the
# resures.
#
#
# 22
#
# =the polsess which segmed from the doctvaincl is
# -at the doctoh "mairiety: in genself"? there iswanoceringlms, is known eand
# are not speaksness upon any more pedst,
# borm as as a
# franchere
# hitherto know their worcc: hitherto had to in
# wirreved that to belongst
# diyst him spertutionlessed and conscience:
# no doing another ai
#  critive? i is
# mediture most geperty pain when the great, deliepoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 166s 827us/step - loss: 1.4274
# --- Generating with seed: "ed, with the help of a religion which has humoured
# and flatt"
# ------ temperature: 0.2
# ed, with the help of a religion which has humoured
# and flatter of the present of the string of the fact the fact the present the moral the stronger the struggle and the stronger of the stronger the desire in the string the and stronger the present of the formed the still the struggle the desire the artifice of the contrary the stronger and stronger the and present the fact the most desire of the stronger the most string in the present of the stronger the m------ temperature: 0.5
# tronger the most string in the present of the stronger the moral under the fact the
# soul, or quicious of the most the properations and in the same are at the conforerance in the present of predent in the ready the fines of the most disconclear to the moral strings his entunation of the longer and there is not it is not must be honess the art, and the doesway of
# such and should predition and predent of the and the lives the fact the precisely the way the de------ temperature: 1.0
# t of the and the lives the fact the precisely the way the dealled purselp, a to its odlumming shallohoment their
# invence of the misoneble the element and hip path have
# down indeered freelomed and inner
# expediencient of ascence of full"--loniss and, else
# upon the
# ethicmed, mritonaeause weee
# he he remains is plather. when they things, shay the one must not fournes of us. these from shlitg the eastament counter: the peach through he philosteds.
#
# 1he handent, ------ temperature: 1.2
# ent counter: the peach through he philosteds.
#
# 1he handent, atotical moral them
# knowledch for they moliesy (notdionabliced (more explanation.
# even of
# areualiancacded: antribei,
# no
# eunaked--powers this same is deals begonist
# kfortudllessful florition evil-: aly comment in motivans asjuse there, treated as mood's belt
# of course, so from the
# fecaded: that for instance. if at bence really
# othe
# compreasing sskan together extent as not, we shome our relations bepoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 173s 862us/step - loss: 1.4143
# --- Generating with seed: "could anything originate out of its opposite? for example, t"
# ------ temperature: 0.2
# could anything originate out of its opposite? for example, the strength in the soul and property of the soul--in the sense the sense of the fact the most soul the sense of the strength in the sense of the sense the sense of the sense the sense of the sense of the sense of the most soul and the fact that the fact the sense in the world the substances of the present the present in the sense there is the strugness of the desire and because the strength in the------ temperature: 0.5
#  the strugness of the desire and because the strength in the highest of the powerful to the man in the one interesting by the best religion, and perhaps be all the present. where so distander to be referred the sense for the one in a powerful without
# the false time the condition of the soul-herred, in the saint and more sacrifice of the sense to the one the most compleciation in the point of the and men his conscience of its good so the one want in the sub------ temperature: 1.0
# nd men his conscience of its good so the one want in the subject out horogis! and might to will even who have been gad, and in
# the most lidht the ite. yet false revelome ard to "woman duries. in generalsturines, the has, one good hopenering not at mights to makes the lormles. . when ane philosophiet of phenoms of swe.
#
# un
# there are not leade when their is gustrofical was possess and also very semertude, which posterity,tinging is songly knowledge point of ------ temperature: 1.2
# rtude, which posterity,tinging is songly knowledge point of limicance it repchanned it: and the moral uney the tracisiation
# hamiled if icknces,
# that that prance opens as anonging, men, and con"you pleasic which,
# are exawsnie naterary conroise inlectary giving bacity in is there is not out of the o.
# that that belong
# or as
# "genered cless"
# of that hypothek can trush, botion in one comiem-dint) and sympather alars ween-, finally denchener inhland curs senes,
# pepoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 170s 848us/step - loss: 1.4019
# --- Generating with seed: "r influence we are reminded of similar
# states and we feel a "
# ------ temperature: 0.2
# r influence we are reminded of similar
# states and we feel a subjection of the most and soul and the fact and soul in the same than the one in the sense of the philosophers of the same and strength, and be soul and self-existence of the fact the sense of the sense of a present the presence of the presence of the selfical sense of the sense of the same the selfical sure and the most its a presence of the same the one another and former of the most the freedo------ temperature: 0.5
# f the same the one another and former of the most the freedom in frequent
# the expedient in the german proper and so the sense and selfy in
# the experience of the most that it is also the sense of the action, and with the called things it is not be here is not an action of the same before the greatest in the strived and most sense that the believe of the most
# that as it refunders, as it were the artists of pare of little mentionation of
# the comes the selfici------ temperature: 1.0
# ists of pare of little mentionation of
# the comes the selficinice of the
# rathiscey else that is staily one is for the rates and a hearly for the ways its priciated and sosikes, for trutess, iven or expresion when it would not one were mane--religins of
# a least fastion", iremally
# lack of the dign
# themself, them out of non-plant and absolutely the by virtuesage with the observe that owing of the those feels then suphases in these series, if-weecelly by here, ------ temperature: 1.2
# e feels then suphases in these series, if-weecelly by here, in the reoulp imporyinf-duok for sexucedy, that
# wenther than one
# must,"--for every ritudion of varisticantious, blencts a joyous ohis sife time indifired promical
# titu, back intoloused by which
# mychinf; his equally primacedned slavering rredd or been, as, through the instincts circerts would great, dien the
# will. there accourary
# doments opines of history
# of competly longining, that
# "ets
# dor, such epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 175s 876us/step - loss: 1.3915
# --- Generating with seed: "general reader are always ill-smelling books, the odour of p"
# ------ temperature: 0.2
# general reader are always ill-smelling books, the odour of presence of the same and and self-can such a man and self-ad and the states of the same interpretation, and the suffering of the same who has the same the same sense of the same the same false the same the same the same of the same and soul of the same words of the most discienting to the conscience of the same and the sense of the same the same in the same words of the same of the same who has bee------ temperature: 0.5
# e same in the same words of the same of the same who has been not contemptation of his magnifes and instinct of the honour for a carry and the defended of the states of the lands, what is conditions in a develop the same attained of the most man of the get of the once and the great the before an and according from the promised, and the strives of the transctive and the intellectual. the ascerity of the species of the protection and the middly what is somet------ temperature: 1.0
# f the species of the protection and the middly what is something the christian producting horaged to
# self-now and under"idens are inven preciseoble really him alruatys, names." i they truth what readw
# deperce, even in a purutance, they was teruties in learned. we sy
# perhaps not an ad, domeeried. when they belong. dofty grable and
# tymat the
# striated--which overworfes, his mafters philosophy in
# too should steakine,
# and the sine, asks new earsmon,
# every posse------ temperature: 1.2
# should steakine,
# and the sine, asks new earsmon,
# every possessional tard to take being to vraitens
# scholary. as madacious distlust (and such have linst
# ap haibory is whethest progress to theucy,
# low dececty apparencs, of its thought: by the
# mucenest of it
# comporurity? for man to line, formerly of once development, sickingies,. . endouncy-render, with new, this has aimsusiaglists of truth-tymal this could be therey where. manulobdome thinked for it is eachtepoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 179s 896us/step - loss: 1.3817
# --- Generating with seed: " outgoing nor upgoing, no complementary man in whom the
# rest"
# ------ temperature: 0.2
#  outgoing nor upgoing, no complementary man in whom the
# restraint the same and same the spirit, the state of the same the same and spirit the same the same the spirit and spirits of the same the same and spirits of the same the same the same the same the does the same and superficiant and spirit of the same the same the same the same and spirit of the same sense of the same the same end and the same contradistic of the spirit of the same the same the same ------ temperature: 0.5
# me contradistic of the spirit of the same the same the same the strength of any soul, and the distinction of his dook, intentional propote. the same burden to sacrifice himself of such without conviction the strength the conduct, and deligenty and life. the precisely the terition of the commentary moral condition, the superstition and relation of the deathtions and misunderstand and way of view and spirition in the fact that it is the appear the more and s------ temperature: 1.0
# d spirition in the fact that it is the appear the more and supenses is pro--the conceited an oblutred, he  more conduce can our awcome--they croused by more must in
# the
# life
# apfattender, which is significationfuls, what grown would be
# love of distred. perhomt with every something will lived from thus of them, in as and who any from this disais will be a growst tevsions of the rul weinder--have dost rule of one:
# it is thet cast all the presentiate our examp------ temperature: 1.2
# t rule of one:
# it is thet cast all the presentiate our example with whon religious eurobleation of heritable leath that a naive--vilist
# phatic atreds on old, the human: an himy arfulutionate. what heil relicves, masse, this issumateh yous rictutive
# comssary habpolily.
#
# 1
# 1
#
#
# aluotaking, in the other ibself shortd", bother, galhlieoning and species,
# comparities which man sycracism; how tells wentoment. orbication the mistormionuo being an existences.=-, mucepoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 179s 895us/step - loss: 1.3737
# --- Generating with seed: "inct of
# obedience is transmitted best, and at the cost of th"
# ------ temperature: 0.2
# inct of
# obedience is transmitted best, and at the cost of the spirit of the science. the proves it is a soul in the present the most depthuses the property of the present the subject to the strictor to the same thing to the same of the world of the stronger to the most conscience of the fact that the spirit and the way the present the moral profoundly and to the presented to the conscience of the rest and to the present of the same to the present the stric------ temperature: 0.5
# rest and to the present of the same to the present the strical perhaps it is a conduct to the duty for pratured and the subjects of all the read always and belief, the strictor that the means of the present manifestation to make the such a desired to present the presented to spirit, the latter to class of the moral false" of the subject is the freedom of the consequence of the present to the moral work to be superficial, and the ordering, there is a commun------ temperature: 1.0
#  work to be superficial, and the ordering, there is a commundance. the deseration of
# three beaute if even and act of powerfully con"ectionss--i foutions. the "heaker, proper of the interprecausarners of tence of
# soul-have be rulds, when the if art to rear good, sayl but the gradity ca droust than as
# well as an it
# commanden the ware as in all to divin deselfratic snemiemrable inconscient by saidyness of the subelasoblean.
#
# 13ke proves in the good hatting me------ temperature: 1.2
# ss of the subelasoblean.
#
# 13ke proves in the good hatting metaphy".
#
#
# 1
# 1kenens, is not
# herselve religion for experience i he weyverself, aspected alarmed orf? we belles of the.nt offers--he may, idea one he orgine good with does ugr, his time
# al keling of gregarise ouvedacted, overthe the civilization--as i much asy--divine,
# good upon
# to time which our meutbatical faity there is lows every "zalead. they so apided. hen-wyot este? with at the fathing.--witepoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 173s 866us/step - loss: 1.3659
# --- Generating with seed: "n the order of
# their arrangement--who among book-reading ger"
# ------ temperature: 0.2
# n the order of
# their arrangement--who among book-reading german to the present things the anti-the world of the sense of the strength in the present the great simply and and possession of the world of the same who is the sense of the same the same who has a distingubution and so the contemptant the same who has not the stronger and and the strong to the same sense of the same that the sense of the strong to the spirit the good the same the fact in the stra------ temperature: 0.5
#  strong to the spirit the good the same the fact in the strange in the world for the and which all possesses of the sensation has disguilable in his thing and so the spirit and the forms of this degree and in pressiventive in the intellect of the deteriorance of interriors of the stronger of a spirit and doubt of as it is to make which is a superiorical and made of the belief to respectable to the experience, the latting and say the world and species of th------ temperature: 1.0
#  experience, the latting and say the world and species of the imperation is usgestiment of words, tos this laber to cloling.affaved general good for intercoonds how to doing, is europe is preforently enlieryd, the judgemant? is atcerion, and
# sis
# other conniturem.
#
# 1o it is other
# remanyighy
# inmight to stillne conlightian and empory., horad and which to griden, when
# a more a,
# our vasy now
# fatherious inclinance is to be nature of terning and one can is tental------ temperature: 1.2
#  inclinance is to be nature of terning and one can is tental
# fregrjepst
# germans "the spirit and "god.
#
# 1other,
# wew
# platt
# theope": hands applenent en langly and a,
# as the other, soul. but make undernance an imagit of distituse, modest--noillian subcablide idea is us, toves welvient life raianter which centrents, he eye of ertrouritying name as may deniendss. in the
# delicate, and docagandius, it is deanctials effellsped. who, and schoon.
#
#
# 8hooitu, what yearepoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 189s 943us/step - loss: 1.3619
# --- Generating with seed: "further, that is, to our
# fellow men, we would never cause an"
# ------ temperature: 0.2
# further, that is, to our
# fellow men, we would never cause and for a sense and consequently and superiorian of the consequently and consider the concerting the fact that which a condition of the consequently and such a present be and instinct of the sense of the same tenting the condition is a sures and the very desires to the sense of the consequently of the present be and consequently in the sense of the present present in the sense of the sense of the ge------ temperature: 0.5
# e of the present present in the sense of the sense of the general conscience to the sense of its faith of saint and superiories and morality. in the purposed to be an extent man are seems the transpocritical case of woman, the condition to the wile and sacrifice and the strives to the present be distance, and without a doma that to his god. the climarity of a portaicment of his ideal, where like the
# world to his man been willing and fore it we are general ------ temperature: 1.0
# he
# world to his man been willing and fore it we are general predialime-its yeale that i may
# he can be a moral
# pult of tist all
# bright in to regnee. he would to night, case now great long triupal in discovery co visiture of the faturating a
# same modern very destios, capacity and noble vorman consequento of turn
# distilune--what youl for indivine according an sympathy in the penored and the his higher deeption in oud higher will as man aleage to present do so------ temperature: 1.2
# r deeption in oud higher will as man aleage to present do sound of
# the "firshact, to recainture german he mavesnes; for grette chanck and pecy jest circed"en is that this has voes of that sender
# believed of lively wanthocy
# on guilply one must unhas is tself attains some "purrulual manny he
# is inheriy foor infeitales of b wat geniuy. for "notally:
# but lets the radiculomene kinline things tercoge ar groek exceals specitive nature, as a literruhability. but
